# %%
import numpy as np
import matplotlib.pyplot as plt
#

from CalibrationFunc import GetData, plotAndFind, plotWithout, GetKoefs, GetKoefs_LIN_VERS

Detector = 'EJ301'

# %%
Energies = []
Channels = []

# %%
#2.04 MeV

Energy = 2040
Hist = GetData(Energy, Detector)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [210, 300], [0, 4e3], [0, 350], modSave = 1, koef = 2, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#2.52 MeV

Energy = 2520
Hist = GetData(Energy, Detector)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [270, 400], [0, 2.5e3], [0, 400], modSave = 1, koef = 8, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#3.94 MeV

Energy = 3940
Hist = GetData(Energy, Detector)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [570, 800], [0, 2.5e3], [0, 8e2], modSave = 1, koef = 12, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#4.53 MeV

Energy = 4530
Hist = GetData(Energy, Detector)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [700, 850], [0, 5e3], [0, 8.5e2], modSave = 1, koef = 16, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#5.51 MeV

Energy = 5510
Hist = GetData(Energy, Detector)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [930, 1100], [0, 2.7e3], [0, 11e2], modSave = 1, koef = 16, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
Energies = (np.array(Energies))
Channels = (np.array(Channels))


Energies = Energies / 1.e3 #MeV
Channels = Channels / 1.e3 #kilo

# %%
#light func

v0 = np.array([3.2, 103, 0.03, 1.004])
v = GetKoefs(Energies, Channels, v0, modSave = 1, Detector = Detector)


#v = [3.285, 103.4, 0.03017, 1.00428]

str = 'L = ' 
str += "{:.3f}".format(v[0]) + 'E - '
str += "{:.1f}".format(v[1]) + '(1 - exp(-'
str += "{:.5f}".format(v[2]) + 'E^('
str += "{:.5f}".format(v[3]) + ')))'

print(str)
# Out:
# L = 0.422E - 104.7(1 - exp(-0.00356E^(0.75153)))

# %%
#Energy func
v0 = [1.0, 0.66]
v = GetKoefs_LIN_VERS(Energies, Channels, v0, modSave = 1, Detector = Detector)

print(v)

#v = [3.285, 103.4]

#str = 'L = ' 
#str += "{:.3f}".format(v[0]) + 'E - '
#str += "{:.1f}".format(v[1]) + '(1 - exp(-'
#str += "{:.5f}".format(v[2]) + 'E^('
#str += "{:.5f}".format(v[3]) + ')))'

#print(str)
# Out:
# [5.504124364608531, 0.6825200447523173]
