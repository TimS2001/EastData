# %%
import numpy as np
import matplotlib.pyplot as plt
#

from CalibrationFunc import GetData, plotAndFind, plotWithout, GetKoefs

Detector = 'BC501A'

# %% [markdown]
# Work with Calibration file.
# Data is used from Read_scale_data directory
#
# There is Energy parameter, that have to same as a energy from files
# For example file 'Read_scale_data\exp_data\BC501A_N2040.mat' and Energy 2040 keV
#
# There are two main function:
# The first helps to find main peak - plotWithout()
# The second calculates Energy and Resolution of peak, and after plots graph - plotAndFind()

# %%
Energies = []
Channels = []

# %%
#2.04 MeV

Energy = 2040
Hist = GetData(Energy)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [215, 350], [0, 8e3], [0, 350], modSave = 1, koef = 2, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#2.52 MeV

Energy = 2520
Hist = GetData(Energy)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [300, 450], [0, 2.5e3], [0, 450], modSave = 1, koef = 8, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#3.94 MeV

Energy = 3940
Hist = GetData(Energy)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [600, 880], [0, 3e3], [0, 8.5e2], modSave = 1, koef = 16, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#4.53 MeV

Energy = 4530
Hist = GetData(Energy)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [720, 1000], [0, 5e3], [0, 10.5e2], modSave = 1, koef = 16, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#5.51 MeV

Energy = 5510
Hist = GetData(Energy)

#plotWithout(Hist, np.str_(Energy))
Channel = plotAndFind(Hist, np.str_(Energy), [960, 1300], [0, 1.2e3], [0, 14e2], modSave = 1, koef = 16, Detector = Detector)

Energies.append(Energy)
Channels.append(Channel)

# %%
#light func
Energies = (np.array(Energies))
Channels = (np.array(Channels))




Energies = Energies / 1.e3 #MeV
Channels = Channels / 1.e3 #kilo
v = GetKoefs(Energies, Channels, modSave = 1, Detector = Detector)


#v = [3.285, 103.4, 0.03017, 1.00428]

str = 'L = ' 
str += "{:.3f}".format(v[0]) + 'E - '
str += "{:.1f}".format(v[1]) + '(1 - exp(-'
str += "{:.5f}".format(v[2]) + 'E^('
str += "{:.5f}".format(v[3]) + ')))'

print(str)
# Out:
# L = 0.318E - 1.0(1 - exp(-0.28174E^(0.78858)))
